# %%
import numpy as np
import scipy.io

# %%
mat_file = 'C:/Users/guill/bachelor/CO2-lab/zzz.mat' # Desktop
data = scipy.io.loadmat(mat_file)
modelThickness = 0.2
caprockDepth = data['zzz'] + modelThickness
[nx,ny] = np.shape(caprockDepth)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/scipy/io/matlab/mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except IOError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/guill/bachelor/CO2-lab/zzz.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 mat_file = 'C:/Users/guill/bachelor/CO2-lab/zzz.mat' # Desktop
# ----> 2 data = scipy.io.loadmat(mat_file)
#       3 modelThickness = 0.2
#       4 caprockDepth = data['zzz'] + modelThickness
#
# File /usr/lib/python3/dist-packages/scipy/io/matlab/mio.py:224, in loadmat(file_name, mdict, appendmat, **kwargs)
# ...
